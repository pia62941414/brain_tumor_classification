# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Installing collected packages: keras
# Successfully installed keras-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.8.0-cp310-cp310-win_amd64.whl (438.0 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from tensorflow) (4.1.1)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.46.0-cp310-cp310-win_amd64.whl (3.5 MB)
# Collecting gast>=0.2.1
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-win_amd64.whl (35 kB)
# Requirement already satisfied: setuptools in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from tensorflow) (61.2.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.20.1-cp310-cp310-win_amd64.whl (903 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.25.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from tensorflow) (1.16.0)
# Collecting numpy>=1.20
#   Downloading numpy-1.22.3-cp310-cp310-win_amd64.whl (14.7 MB)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from tensorflow) (2.8.0)
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.6.0-cp310-cp310-win_amd64.whl (2.8 MB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.5.30)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=fc27143906a8f051710f0ef595853ce7e9b0bc7690f1c860e4a823bef97b3070
#   Stored in directory: c:\users\priyanshu sharma\appdata\local\pip\cache\wheels\a1\49\46\1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built termcolor
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, tf-estimator-nightly, termcolor, tensorflow-io-gcs-filesystem, tensorboard, opt-einsum, libclang, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 charset-normalizer-2.0.12 flatbuffers-2.0 gast-0.5.3 google-auth-2.6.6 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.46.0 h5py-3.6.0 idna-3.3 keras-preprocessing-1.1.2 libclang-14.0.1 markdown-3.3.7 numpy-1.22.3 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.20.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.25.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109 urllib3-1.26.9 werkzeug-2.1.2 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from pandas) (1.22.3)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six>=1.5 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.2 pytz-2022.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (1.22.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp310-cp310-win_amd64.whl (55 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from matplotlib) (1.22.3)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.0-cp310-cp310-win_amd64.whl (3.3 MB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.2 pillow-9.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.1.0
#   Downloading scipy-1.8.0-cp310-cp310-win_amd64.whl (37.0 MB)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (from scikit-learn->sklearn) (1.22.3)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=ef817e5bbd5fce6196950a099d3d5afff5514ed7f10a551f0aff942ba56bb11b
#   Stored in directory: c:\users\priyanshu sharma\appdata\local\pip\cache\wheels\9b\13\01\6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 scipy-1.8.0 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\priyanshu sharma\anaconda3\envs\environment1\lib\site-packages (9.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
from PIL import Image

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder()

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'brain_tumor_dataset/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"brain_tumor_dataset/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 7s 2s/step - loss: 41.6290 - val_loss: 118.4549
# Epoch 2/30
# 3/3 [==============================] - 5s 2s/step - loss: 22.6794 - val_loss: 60.7308
# Epoch 3/30
# 3/3 [==============================] - 5s 2s/step - loss: 14.1339 - val_loss: 68.3576
# Epoch 4/30
# 3/3 [==============================] - 5s 2s/step - loss: 8.1724 - val_loss: 25.4823
# Epoch 5/30
# 3/3 [==============================] - 5s 2s/step - loss: 3.2220 - val_loss: 12.8530
# Epoch 6/30
# 3/3 [==============================] - 5s 2s/step - loss: 4.9955 - val_loss: 12.7242
# Epoch 7/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.6572 - val_loss: 27.3474
# Epoch 8/30
# 3/3 [==============================] - 5s 2s/step - loss: 2.6246 - val_loss: 32.3391
# Epoch 9/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.9432 - val_loss: 30.1712
# Epoch 10/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.7902 - val_loss: 24.4694
# Epoch 11/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.6922 - val_loss: 17.1537
# Epoch 12/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1958 - val_loss: 13.6043
# Epoch 13/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1610 - val_loss: 11.9715
# Epoch 14/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.6924 - val_loss: 10.4160
# Epoch 15/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.2909 - val_loss: 10.3628
# Epoch 16/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.2895 - val_loss: 10.1462
# Epoch 17/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1098 - val_loss: 9.8373
# Epoch 18/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.2726 - val_loss: 9.7720
# Epoch 19/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0358 - val_loss: 9.4030
# Epoch 20/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0239 - val_loss: 8.9646
# Epoch 21/30
# 3/3 [==============================] - 5s 2s/step - loss: 2.7708e-07 - val_loss: 8.5994
# Epoch 22/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1351 - val_loss: 8.0231
# Epoch 23/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0152 - val_loss: 6.9318
# Epoch 24/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0050 - val_loss: 6.5222
# Epoch 25/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1051 - val_loss: 6.6089
# Epoch 26/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0011 - val_loss: 6.7845
# Epoch 27/30
# 3/3 [==============================] - 5s 2s/step - loss: 2.4036e-05 - val_loss: 6.9478
# Epoch 28/30
# 3/3 [==============================] - 5s 2s/step - loss: 5.4019e-07 - val_loss: 7.0457
# Epoch 29/30
# 3/3 [==============================] - 5s 2s/step - loss: 1.0361e-05 - val_loss: 7.0939
# Epoch 30/30
# 3/3 [==============================] - 5s 2s/step - loss: 2.8805e-05 - val_loss: 7.1083

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"brain_tumor_dataset/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"brain_tumor_dataset/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 100.0% Confidence This Is A Its a Tumor
